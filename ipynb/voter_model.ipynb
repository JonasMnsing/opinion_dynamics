# %%
import numpy as np
import networkx as nx
import matplotlib.pyplot as plt

# %%
avg_opinion = np.load(f"../data/avg_opinion.npy")
int_density = np.load(f"../data/int_density.npy")
con_matrix  = np.load(f"../data/connection_matrix.npy")

# %%
fig = plt.figure()
ax  = fig.add_subplot()
ax.plot(avg_opinion)
ax.set_xlabel("Iteration")
ax.set_ylabel("Average Opinion")
# Out:
# Text(0, 0.5, 'Average Opinion')

# %%
fig = plt.figure()
ax  = fig.add_subplot()
ax.plot(int_density)
ax.set_xlabel("Iteration")
ax.set_ylabel("Interface Density")
# Out:
# Text(0, 0.5, 'Interface Density')

# %%
G   = nx.from_numpy_array(con_matrix)
pos = nx.spring_layout(G)

nx.draw(G, pos=pos, node_size=50, )
