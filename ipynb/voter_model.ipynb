# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
avg_opinion = np.load("../avg_opinion.npy")
int_density = np.load("../int_density.npy")

# %%
fig = plt.figure()
ax  = fig.add_subplot()
ax.plot(avg_opinion)
