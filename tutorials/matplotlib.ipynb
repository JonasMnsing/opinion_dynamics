# %% [markdown]
# # Introduction to Matplotlib
# ---

# %% [markdown]
# - Library to display and visualize data
# - Serves also as a base library for many other libraries such as Seaborn, Plotly, pandas
#
# https://matplotlib.org/stable/tutorials/index

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# First we need some data
N   = 1000
arr = np.cumsum(np.random.normal(0,1,N))

# %% [markdown]
# **Simple Line Plots**
# - In general a plot consists of a figure object or canvas / background
# - An Axes object serving as the coordinate system on which we display the data
# - An the data itself

# %%
# Make a figure object called fig
fig = plt.figure()

# Add a coordinate system called ax
ax = fig.add_subplot()

# Display the data, and label it for legend
ax.plot(arr, label='frist measurement')

# Define x, y Labels
ax.set_xlabel("Time")
ax.set_ylabel("Data")

# Add a legend
ax.legend()

# Add grids
ax.grid()

# %% [markdown]
# **Multi-Plots**
# - We might want to display different runs in a single plot
# - Or in multiple plots using `fig.add_subplot(n_row,n_cols,nth_plot)`

# %%
# Again some data
N   = 1000
arr = np.cumsum(np.random.normal(0,1,size=(N,4)),axis=0)

# %%
# Make a figure object called fig
fig = plt.figure()

# Add a coordinate system called ax
ax = fig.add_subplot()

# Display the data, and label it for legend
for i in range(4):
    ax.plot(arr[:,i], label=f'Run {i}')

# Define x, y Labels
ax.set_xlabel("Time")
ax.set_ylabel("Data")

# Add a legend
ax.legend()

# Add grids
ax.grid()

# %%
# Make a figure object called fig with a constrained layout (best for multiplots)
fig = plt.figure(layout='constrained')

# Iterate over each run
for i in range(4):
    # And make a new subplot in a 2x2 grid of plots with i+1 as the plot count
    ax = fig.add_subplot(2,2,i+1)
    ax.plot(arr[:,i], label=f'Run {i}')

    # Define x, y Labels
    ax.set_xlabel("Time")
    ax.set_ylabel("Data")

    # Add a legend
    ax.legend()

    # Add grids
    ax.grid()

# %% [markdown]
# - Use Style Sheets for different plot styles
#
# https://matplotlib.org/stable/gallery/style_sheets/style_sheets_reference.html

# %%
with plt.style.context("classic"):

    # Make a figure object called fig
    fig = plt.figure()

    # Add a coordinate system called ax
    ax = fig.add_subplot()

    # Display the data, and label it for legend
    for i in range(4):
        ax.plot(arr[:,i], label=f'Run {i}')

    # Define x, y Labels
    ax.set_xlabel("Time")
    ax.set_ylabel("Data")

    # Add a legend
    ax.legend()

    # Add grids
    ax.grid()

# %% [markdown]
# **Different Plot Functions**

# %%
# Data
N       = 10000
arr1    = np.random.normal(0,5,size=(N))
arr2    = np.random.normal(0,1,size=(N))
arr3    = np.random.normal(4,1,size=(N))

# %%
with plt.style.context("fivethirtyeight"):

    fig = plt.figure()
    ax  = fig.add_subplot()
    h   = ax.hist(arr1, bins=100, label='Run 1')
    h   = ax.hist(arr2, bins=100, label='Run 2')
    h   = ax.hist(arr3, bins=100, label='Run 3')
    ax.legend()

# %%
# Create sample 2D data for phase plot
x = np.linspace(-5, 5, 100)
y = np.linspace(-5, 5, 100)
X, Y = np.meshgrid(x, y)
Z = np.sin(X) * np.cos(Y)

# Create the phase plot
fig = plt.figure(figsize=(8, 6))
ax = fig.add_subplot()
im = ax.imshow(Z, extent=[-5, 5, -5, 5], origin='lower', cmap='viridis')

# Add colorbar and labels
plt.colorbar(im)
ax.set_xlabel('X')
ax.set_ylabel('Y')
# Out:
# Text(0, 0.5, 'Y')

# %% [markdown]
# ### Seaborn Library

# %%
import seaborn as sns

arr = np.array([arr1, arr2, arr3])
fig = plt.figure()
ax  = fig.add_subplot()
ax  = sns.histplot(arr, bins=100, ax=ax, multiple="layer")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[105], line 6
#       4 fig = plt.figure()
#       5 ax  = fig.add_subplot()
# ----> 6 ax  = sns.histplot(arr, bins=100, ax=ax, multiple="layer")
#
# File ~/.local/lib/python3.12/site-packages/seaborn/distributions.py:1416, in histplot(data, x, y, hue, weights, stat, bins, binwidth, binrange, discrete, cumulative, common_bins, common_norm, multiple, element, fill, shrink, kde, kde_kws, line_kws, thresh, pthresh, pmax, cbar, cbar_ax, cbar_kws, palette, hue_order, hue_norm, color, log_scale, legend, ax, **kwargs)
#    1405 estimate_kws = dict(
#    1406     stat=stat,
#    1407     bins=bins,
#    (...)
#    1411     cumulative=cumulative,
#    1412 )
#    1414 if p.univariate:
# -> 1416     p.plot_univariate_histogram(
#    1417         multiple=multiple,
#    1418         element=element,
#    1419         fill=fill,
# ...

# %%
arr = np.array([arr1, arr2, arr3]).T
fig = plt.figure()
ax  = fig.add_subplot()
ax  = sns.boxplot(arr, ax=ax)
